# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#plot data
#Series
data = pd.Series(np.random.randn(1000),index=np.arange(1000))
data = data.cumsum()
data.plot()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#DataFrame
data = pd.DataFrame(np.random.randn(1000,4),
                   index=np.arange(1000),
                   columns=list("ABCD"))
data = data.cumsum()
print(data.head())
data.plot()
plt.show
# Out:
#           A         B         C         D
# 0  0.442583  0.723504  0.520207  1.699847
# 1 -0.060753  1.578075  0.979478  1.028357
# 2  0.241121  2.769693  1.375487  1.148363
# 3  0.581305  3.607544  2.375380  0.210364
# 4  0.157827  4.577446  3.332053  0.305346
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
data.plot.scatter(x='A',y='B',color='DarkBlue',label='Class 1')

# %%
ax = data.plot.scatter(x='A',y='B',color='DarkBlue',label="Class1")
data.plot.scatter(x='A',y='C',color='DarkGreen',label='Class2',ax=ax)
